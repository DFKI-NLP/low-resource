# %%
import matplotlib.pyplot as plt
import numpy as np
iter_num=6
x = np.arange(1,iter_num)

fig, ax = plt.subplots()
ax.set(xlabel='Iterations', ylabel='Recall')
#title='COMPONENT&PRODUCT&ATTRIBUTE recall score though iteration'
ax.grid()

component_pu = [0.6190345216067606, 0.7290041365814586, 0.7438101186714426, 0.7588616615667485, 0.7635589205283774, 0.7573179177673479]
component_basic=[0.6145206449732169, 0.6992917148831285, 0.7134173225727408, 0.7179844327945435, 0.7277542729335212, 0.7269661967440798]

product_basic=[0.6352663662790035, 0.6683646084215183, 0.6675731180949632, 0.6645532023994092, 0.6750945321995876, 0.679335539709062]
product_pu=[0.6681844702987925, 0.7103938996393329, 0.7268746727982149, 0.7527548965024308, 0.7509646242542569, 0.7023435384997796]


attri_basic=[0.6048478414833292, 0.6045294262206127, 0.606876239049252, 0.6091837498813499, 0.6128631767556671, 0.6135589602759123]
attri_pu=[0.6011880656072826, 0.61113354345419, 0.6112121474472729, 0.6115305627099893, 0.6148522723250487, 0.6145142060640616]

category_colors = ['#f58518', '#4c78a8']

#plt.ylim(0.7 , 0.8)
#lines = plt.plot(x,precision_overall) #,
plt.plot(x,component_pu[:iter_num-1], color='#f58518', marker='D', linestyle='solid',label='Comp, PU' ) #,f1_overall
plt.plot(x,component_basic[:iter_num-1], color='#f58518', marker='D', linestyle='dotted', label='Comp, Basic') #,f1_overall

plt.plot(x,product_pu[:iter_num-1],color='#4c78a8', marker='x', linestyle='solid', label='Prod, PU') #,f1_overall
plt.plot(x,product_basic[:iter_num-1], color='#4c78a8', marker='x', linestyle='dotted',  label='Prod, Basic' ) #,f1_overall

plt.plot(x,attri_pu[:iter_num-1], color='#3faa59', marker='s', linestyle='solid',label='Attr, PU' ) #,f1_overall
plt.plot(x,attri_basic[:iter_num-1],color='#3faa59', marker='s', linestyle='dotted', label='Attr, Basic') #,f1_overall

plt.ylim(0.59, 0.81)
plt.xticks(x)
plt.legend(ncol=3, 
              loc='upper center', fontsize='small')
#plt.legend(loc='upper left') #loc='lower right'
plt.show()
fig.savefig("recall_combine.png")
